# %%
import pandas as pd
import pickle

# %%
import time
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %%
sellers = pd.read_pickle("PROGRAMACAO/teste/sellers.pkl")
sellers.head(3)
# Out:
#        id       nickname registration_date country_id user_type  points  \
# 0  124201         AI1999        1999-12-23         BR    normal   27838
# 1  125058      MAISFPSBR        1999-12-27         BR    normal     150
# 2  349856  CONSTRUMAR-LC        2000-06-15         BR    normal    2223
#
#                                          permalink  status  \
# 0         http://perfil.mercadolivre.com.br/AI1999  active
# 1      http://perfil.mercadolivre.com.br/MAISFPSBR  active
# 2  http://perfil.mercadolivre.com.br/CONSTRUMAR-LC  active
#
#                   city state level_id power_seller_status  \
# 0            São Paulo    SP  5_green                gold
# 1  Santana de Parnaíba    SP  5_green            platinum
# 2            Marapoama    SP  5_green            platinum
#
#    transactions_completed
# 0                    4134
# 1                    1321
# 2                   11730

# %%
sellers['registration_date'] = sellers['registration_date'].dt.date

# %%
sellers.head(3)
# Out:
#        id       nickname registration_date country_id user_type  points  \
# 0  124201         AI1999        1999-12-23         BR    normal   27838
# 1  125058      MAISFPSBR        1999-12-27         BR    normal     150
# 2  349856  CONSTRUMAR-LC        2000-06-15         BR    normal    2223
#
#                                          permalink  status  \
# 0         http://perfil.mercadolivre.com.br/AI1999  active
# 1      http://perfil.mercadolivre.com.br/MAISFPSBR  active
# 2  http://perfil.mercadolivre.com.br/CONSTRUMAR-LC  active
#
#                   city state level_id power_seller_status  \
# 0            São Paulo    SP  5_green                gold
# 1  Santana de Parnaíba    SP  5_green            platinum
# 2            Marapoama    SP  5_green            platinum
#
#    transactions_completed
# 0                    4134
# 1                    1321
# 2                   11730

# %%
sellers = sellers[['id', 'nickname', 'registration_date', 'user_type',
       'points', 'permalink', 'status', 'city', 'state', 'level_id',
       'power_seller_status', 'transactions_completed']]

# %%
sellers.columns
# Out:
# Index(['id', 'nickname', 'registration_date', 'user_type', 'points',
#        'permalink', 'status', 'city', 'state', 'level_id',
#        'power_seller_status', 'transactions_completed'],
#       dtype='object')

# %%
(sellers.power_seller_status.str.len().sort_values())
# Out:
# 0       4.0
# 1138    4.0
# 2924    4.0
# 1135    4.0
# 1134    4.0
#        ...
# 3812    NaN
# 4074    NaN
# 4546    NaN
# 4826    NaN
# 4999    NaN
# Name: power_seller_status, Length: 5050, dtype: float64

# %%
atributo = pd.read_pickle("PROGRAMACAO/teste/atributo.pkl")
atributo.head(3)
# Out:
#       id_anuncio              id              name       value_name
# 0  MLB1620161340           BRAND             Marca  NICE - PECCININ
# 1  MLB1620161340  ITEM_CONDITION  Condição do item             Novo
# 2  MLB1620161340           MODEL            Modelo            TX 3C

# %%
tabela_dim = pd.read_pickle("PROGRAMACAO/teste/tabela_dim.pkl")
tabela_dim.head(3)
# Out:
#               id                                              title  \
# 0  MLB1620161340  Controle Remoto Para Portão Peccinin Varias Co...
# 1  MLB1359721693  Controle Remoto Portão Rossi Ntx 433 Nano Atto...
# 2   MLB730238982  Placa Motor Kxh30fs Dz4 Dz3 Dz Nano Rossi Com ...
#
#   listing_type_id                                          permalink  \
# 0    gold_special  https://produto.mercadolivre.com.br/MLB-162016...
# 1    gold_special  https://produto.mercadolivre.com.br/MLB-135972...
# 2    gold_special  https://produto.mercadolivre.com.br/MLB-730238...
#
#                                            thumbnail category_id  \
# 0  http://http2.mlstatic.com/D_672731-MLB43279464...   MLB270238
# 1  http://http2.mlstatic.com/D_700327-MLB43051389...   MLB270238
# 2  http://http2.mlstatic.com/D_992430-MLB43144475...   MLB270238
#
#                                                 tags  id_seller  \
# 0  brand_verified,good_quality_picture,good_quali...  534713792
# ...

# %%
tratando_fatos = pd.read_pickle("PROGRAMACAO/teste/tratando_fatos.pkl")
tratando_fatos.head(3)
# Out:
#               id   price  available_quantity  sold_quantity  \
# 0  MLB1620161340   31.99                 148           1058
# 1  MLB1359721693   34.77                  76           1330
# 2   MLB730238982  199.24                 159           1008
#
#   shipping_logistic_type        data
# 0            fulfillment  03/04/2021
# 1            fulfillment  03/04/2021
# 2          cross_docking  03/04/2021

# %%
#INPUT YOUR OWN CONNECTION STRING HERE
conn_string = 'postgresql://diego:1234@localhost/hubble'

# %%
#perform to_sql test and print result
db = create_engine(conn_string)
conn = db.connect()

# %%
start_time = time.time()
sellers.to_sql('temp_seller2', con=conn, if_exists='replace', index=False)
print("to_sql duration: {} seconds".format(time.time() - start_time))
# Out:
# to_sql duration: 0.13962960243225098 seconds

# %%
'ENGINE': 'django.db.backends.postgresql',
'NAME': 'hubble',
'USER': 'diego',
'PASSWORD': '1234',
'HOST': 'localhost',
'PORT': '5432',

# %%
engine = create_engine('postgresql+psycopg2://diego:1234@localhost/hubble')
df.to_sql('temp_table', engine, if_exists= 'append')

sql = """
    UPDATE core_vendedor AS f
    SET f.col1 = t.col1
    FROM temp_table AS t
    WHERE f.id = t.id
"""

with engine.begin() as conn:     # TRANSACTION
    conn.execute(sql)

# %%
import pymysql


# Connect to the database
connection = pymysql.connect(host='localhost',
                         user='root',
                         password='12345',
                         db='book')


# create cursor
cursor=connection.cursor()
